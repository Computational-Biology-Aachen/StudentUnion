# %%
from mxlbricks import get_saadat2021, get_matuszynska2016npq
from model_validation import create_report_summary
import mxlbricks.names as n
from mxlpy import units

# %% [markdown]
# # Validating two mxlbrick models

# %% [markdown]
# ## Saadat2021

# %%
m = get_saadat2021()

m.update_reaction(n.rubisco_carboxylase(), unit=units.mmol / (units.liter * units.second)) # Add Vc unit mM/s

create_report_summary(
    model=m,
    pfd=n.pfd(),
    co2=n.co2(),
    vc=n.rubisco_carboxylase(),
    file_prepend="saadat2021",
    flourescence=n.fluorescence(),
    atp=n.atp(),
    nadph=n.nadph(),
    rubp=n.rubp(),
    coeff_rubisco=n.kcat(n.rubisco_carboxylase())
);
# Out:
# 100%|██████████| 100/100 [00:07<00:00, 13.40it/s]
# INFO:root:Downloading 1 NEON DP1.00024.001 files totaling approximately 16.6 MB.

# %% [markdown]
# ## Matuzynska2016

# %%
# TODO: Finish adding args
# MCA does not work because I have not given enough coefficients yet
# TODO: Fix Fmin in Matuszynska2016NPQ model
create_report_summary(
    model=get_matuszynska2016npq(),
    pfd=n.pfd(),
    file_prepend="matuszynska2016npq",
    flourescence=n.fluorescence(),
    atp=n.atp(),
    coeff_psii="k2"
);
# Out:
# INFO:root:Downloading 1 NEON DP1.00024.001 files totaling approximately 16.6 MB.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 # TODO: Finish adding args
#       2 # MCA does not work because I have not given enough coefficients yet
#       3 # TODO: Fix Fmin in Matuszynska2016NPQ model
# ----> 4 create_report_summary(
#       5     model=get_matuszynska2016npq(),
#       6     pfd=n.pfd(),
#       7     file_prepend="matuszynska2016npq",
#       8     flourescence=n.fluorescence(),
#       9     atp=n.atp(),
#      10     coeff_psii="k2"
#      11 );
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/model_validation.py:1111, in create_report_summary(model, pfd, file_prepend, co2, vc, pco2, H_cp_co2, gammastar, r_light, A, flourescence, atp, nadph, rubp, coeff_psii, coeff_psi, coeff_rubisco)
#    1080 """Create markdown file of Model validation.
#    1081
#    1082 Use a MxLpy model to create and save all model validation figs and create a markdown summary file. The figs include:
#    (...)   1103     coeff_rubisco (str | None, optional): Name for Rubisco coefficient in model. Defaults to None.
#    1104 """
#    1106 # TODO: Add PAM assumptions
#    1107 # TODO: Add Day simulation
#    1108 # TODO: Add MCA
#    1109
#    1110 # Create all the validation figs and save them
# -> 1111 create_save_figs(
#    1112     model=model,
#    1113     pfd=pfd,
#    1114     file_prepend=file_prepend,
#    1115     co2=co2,
#    1116     vc=vc,
#    1117     pco2=pco2,
#    1118     H_cp_co2=H_cp_co2,
#    1119     gammastar=gammastar,
#    1120     r_light=r_light,
#    1121     A=A,
#    1122     flourescence=flourescence,
#    1123     atp=atp,
#    1124     nadph=nadph,
#    1125     rubp=rubp,
#    1126     coeff_psii=coeff_psii,
#    1127     coeff_psi=coeff_psi,
#    1128     coeff_rubisco=coeff_rubisco,
#    1129 )
#    1131 # Create markdown summary file
#    1132 mdFile = MdUtils(
#    1133     file_name=f"{Path(__file__).parent / f'{file_prepend}_report_summary.md'}",
#    1134     title=f"{file_prepend} Report Summary",
#    1135 )
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/model_validation.py:1049, in create_save_figs(model, pfd, file_prepend, co2, vc, pco2, H_cp_co2, gammastar, r_light, A, flourescence, atp, nadph, rubp, coeff_psii, coeff_psi, coeff_rubisco)
#    1046 save_matplotlib_figure(plot, file_prepend, "day_simulation")
#    1048 # MCA of photosynthesis control coefficients
# -> 1049 plot, ax = create_mca_fig(
#    1050     model=model,
#    1051     coeff_psii=coeff_psii,
#    1052     coeff_psi=coeff_psi,
#    1053     coeff_rubisco=coeff_rubisco,
#    1054     rubp=rubp,
#    1055     co2=co2,
#    1056 )
#    1058 return
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/model_validation.py:931, in create_mca_fig(model, coeff_psii, coeff_psi, coeff_rubisco, rubp, co2)
#     928         plot_vars.loc[i, :] = np.nan
#     930 # Plot heatmap of MCA results
# --> 931 plot.heatmap(
#     932     plot_vars,
#     933     ax=ax,
#     934 )
#     936 # Set axis labels and if values are NaN set alpha of text to 0.3
#     937 for text in ax.get_yticklabels():
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/mxlpy/plot.py:941, in heatmap(df, ax, title, annotate, colorbar, invert_yaxis, cmap, norm, cax, sci_annotation_bounds, annotation_style)
#     926 def heatmap(
#     927     df: pd.DataFrame,
#     928     *,
#    (...)    938     annotation_style: str = "2g",
#     939 ) -> tuple[Figure, Axes, QuadMesh]:
#     940     """Plot a heatmap of the given data."""
# --> 941     return _create_heatmap(
#     942         ax=ax,
#     943         df=df,
#     944         title=title,
#     945         xlabel=df.index.name,  # type: ignore
#     946         ylabel=df.columns.name,  # type: ignore
#     947         xticklabels=cast(list, df.columns),
#     948         yticklabels=cast(list, df.index),
#     949         annotate=annotate,
#     950         colorbar=colorbar,
#     951         invert_yaxis=invert_yaxis,
#     952         cmap=cmap,
#     953         norm=_norm_with_zero_center(df) if norm is None else norm,
#     954         cax=cax,
#     955         sci_annotation_bounds=sci_annotation_bounds,
#     956         annotation_style=annotation_style,
#     957     )
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/mxlpy/plot.py:917, in _create_heatmap(ax, df, title, xlabel, ylabel, xticklabels, yticklabels, norm, annotate, colorbar, invert_yaxis, cmap, cax, sci_annotation_bounds, annotation_style)
#     913     _annotate_colormap(df, ax, sci_annotation_bounds, annotation_style, hm)
#     915 if colorbar:
#     916     # Add a colorbar
# --> 917     cb = fig.colorbar(hm, cax, ax)
#     918     cb.outline.set_linewidth(0)  # type: ignore
#     920 if invert_yaxis:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/figure.py:1308, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1300         _api.warn_external(
#    1301                 f'Adding colorbar to a different Figure '
#    1302                 f'{repr(mappable_host_fig)} than '
#    1303                 f'{repr(self._root_figure)} which '
#    1304                 f'fig.colorbar is called on.')
#    1306 NON_COLORBAR_KEYS = [  # remove kws that cannot be passed to Colorbar
#    1307     'fraction', 'pad', 'shrink', 'aspect', 'anchor', 'panchor']
# -> 1308 cb = cbar.Colorbar(cax, mappable, **{
#    1309     k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS})
#    1310 cax.get_figure(root=False).stale = True
#    1311 return cb
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:387, in Colorbar.__init__(self, ax, mappable, alpha, location, extend, extendfrac, extendrect, ticks, format, values, boundaries, spacing, drawedges, label, cmap, norm, orientation, ticklocation)
#     384 self.ticklocation = ticklocation
#     386 self.set_label(label)
# --> 387 self._reset_locator_formatter_scale()
#     389 if np.iterable(ticks):
#     390     self._locator = ticker.FixedLocator(ticks, nbins=len(ticks))
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:1163, in Colorbar._reset_locator_formatter_scale(self)
#    1157 def _reset_locator_formatter_scale(self):
#    1158     """
#    1159     Reset the locator et al to defaults.  Any user-hardcoded changes
#    1160     need to be re-entered if this gets called (either at init, or when
#    1161     the mappable normal gets changed: Colorbar.update_normal)
#    1162     """
# -> 1163     self._process_values()
#    1164     self._locator = None
#    1165     self._minorlocator = None
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:1099, in Colorbar._process_values(self)
#    1097     self.norm.vmin = 0
#    1098     self.norm.vmax = 1
# -> 1099 self.norm.vmin, self.norm.vmax = mtransforms.nonsingular(
#    1100     self.norm.vmin, self.norm.vmax, expander=0.1)
#    1101 if (not isinstance(self.norm, colors.BoundaryNorm) and
#    1102         (self.boundaries is None)):
#    1103     b = self.norm.inverse(b)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2184, in Normalize.vmin(self, value)
#    2182 if value != self._vmin:
#    2183     self._vmin = value
# -> 2184     self._changed()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2212, in Normalize._changed(self)
#    2207 def _changed(self):
#    2208     """
#    2209     Call this whenever the norm is changed to notify all the
#    2210     callback listeners to the 'changed' signal.
#    2211     """
# -> 2212     self.callbacks.process('changed')
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:297, in Colorizer.changed(self)
#     292 def changed(self):
#     293     """
#     294     Call this whenever the mappable is changed to notify all the
#     295     callbackSM listeners to the 'changed' signal.
#     296     """
# --> 297     self.callbacks.process('changed')
#     298     self.stale = True
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:589, in _ScalarMappable.changed(self)
#     584 def changed(self):
#     585     """
#     586     Call this whenever the mappable is changed to notify all the
#     587     callbackSM listeners to the 'changed' signal.
#     588     """
# --> 589     self.callbacks.process('changed', self)
#     590     self.stale = True
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:513, in Colorbar.update_normal(self, mappable)
#     510     self.norm = self.mappable.norm
#     511     self._reset_locator_formatter_scale()
# --> 513 self._draw_all()
#     514 if isinstance(self.mappable, contour.ContourSet):
#     515     CS = self.mappable
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:540, in Colorbar._draw_all(self)
#     534 self._short_axis().set_ticks([], minor=True)
#     536 # Set self._boundaries and self._values, including extensions.
#     537 # self._boundaries are the edges of each square of color, and
#     538 # self._values are the value to map into the norm to get the
#     539 # color:
# --> 540 self._process_values()
#     541 # Set self.vmin and self.vmax to first and last boundary, excluding
#     542 # extensions:
#     543 self.vmin, self.vmax = self._boundaries[self._inside][[0, -1]]
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:1099, in Colorbar._process_values(self)
#    1097     self.norm.vmin = 0
#    1098     self.norm.vmax = 1
# -> 1099 self.norm.vmin, self.norm.vmax = mtransforms.nonsingular(
#    1100     self.norm.vmin, self.norm.vmax, expander=0.1)
#    1101 if (not isinstance(self.norm, colors.BoundaryNorm) and
#    1102         (self.boundaries is None)):
#    1103     b = self.norm.inverse(b)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2195, in Normalize.vmax(self, value)
#    2193 if value != self._vmax:
#    2194     self._vmax = value
# -> 2195     self._changed()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2212, in Normalize._changed(self)
#    2207 def _changed(self):
#    2208     """
#    2209     Call this whenever the norm is changed to notify all the
#    2210     callback listeners to the 'changed' signal.
#    2211     """
# -> 2212     self.callbacks.process('changed')
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:297, in Colorizer.changed(self)
#     292 def changed(self):
#     293     """
#     294     Call this whenever the mappable is changed to notify all the
#     295     callbackSM listeners to the 'changed' signal.
#     296     """
# --> 297     self.callbacks.process('changed')
#     298     self.stale = True
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:589, in _ScalarMappable.changed(self)
#     584 def changed(self):
#     585     """
#     586     Call this whenever the mappable is changed to notify all the
#     587     callbackSM listeners to the 'changed' signal.
#     588     """
# --> 589     self.callbacks.process('changed', self)
#     590     self.stale = True
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:513, in Colorbar.update_normal(self, mappable)
#     510     self.norm = self.mappable.norm
#     511     self._reset_locator_formatter_scale()
# --> 513 self._draw_all()
#     514 if isinstance(self.mappable, contour.ContourSet):
#     515     CS = self.mappable
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:540, in Colorbar._draw_all(self)
#     534 self._short_axis().set_ticks([], minor=True)
#     536 # Set self._boundaries and self._values, including extensions.
#     537 # self._boundaries are the edges of each square of color, and
#     538 # self._values are the value to map into the norm to get the
#     539 # color:
# --> 540 self._process_values()
#     541 # Set self.vmin and self.vmax to first and last boundary, excluding
#     542 # extensions:
#     543 self.vmin, self.vmax = self._boundaries[self._inside][[0, -1]]
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorbar.py:1103, in Colorbar._process_values(self)
#    1099 self.norm.vmin, self.norm.vmax = mtransforms.nonsingular(
#    1100     self.norm.vmin, self.norm.vmax, expander=0.1)
#    1101 if (not isinstance(self.norm, colors.BoundaryNorm) and
#    1102         (self.boundaries is None)):
# -> 1103     b = self.norm.inverse(b)
#    1105 self._boundaries = np.asarray(b, dtype=float)
#    1106 self._values = 0.5 * (self._boundaries[:-1] + self._boundaries[1:])
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2692, in _make_norm_from_scale.<locals>.Norm.inverse(self, value)
#    2690 t_vmin, t_vmax = self._trf.transform([self.vmin, self.vmax])
#    2691 if not np.isfinite([t_vmin, t_vmax]).all():
# -> 2692     raise ValueError("Invalid vmin or vmax")
#    2693 value, is_scalar = self.process_value(value)
#    2694 rescaled = value * (t_vmax - t_vmin)
#
# ValueError: Invalid vmin or vmax
# Error in callback <function _draw_all_if_interactive at 0x7a3ff55037e0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/pyplot.py:278, in _draw_all_if_interactive()
#     276 def _draw_all_if_interactive() -> None:
#     277     if matplotlib.is_interactive():
# --> 278         draw_all()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/collections.py:2423, in QuadMesh.draw(self, renderer)
#    2420     ys = self.convert_yunits(offsets[:, 1])
#    2421     offsets = np.column_stack([xs, ys])
# -> 2423 self.update_scalarmappable()
#    2425 if not transform.is_affine:
#    2426     coordinates = self._coordinates.reshape((-1, 2))
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/collections.py:923, in Collection.update_scalarmappable(self)
#     921         # pcolormesh, scatter, maybe others flatten their _A
#     922         self._alpha = self._alpha.reshape(self._A.shape)
# --> 923     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     925 if self._face_is_mapped:
#     926     self._facecolors = self._mapped_colors
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:367, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     337 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     338     """
#     339     Return a normalized RGBA array corresponding to *x*.
#     340
#    (...)    365
#     366     """
# --> 367     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:157, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     155 x = ma.asarray(x)
#     156 if norm:
# --> 157     x = self.norm(x)
#     158 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159 return rgba
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2679, in _make_norm_from_scale.<locals>.Norm.__call__(self, value, clip)
#    2677 t_vmin, t_vmax = self._trf.transform([self.vmin, self.vmax])
#    2678 if not np.isfinite([t_vmin, t_vmax]).all():
# -> 2679     raise ValueError("Invalid vmin or vmax")
#    2680 t_value -= t_vmin
#    2681 t_value /= (t_vmax - t_vmin)
#
# ValueError: Invalid vmin or vmax
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/backend_bases.py:2157, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2157         self.figure.draw(renderer)
#    2158 if bbox_inches:
#    2159     if bbox_inches == "tight":
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/collections.py:2423, in QuadMesh.draw(self, renderer)
#    2420     ys = self.convert_yunits(offsets[:, 1])
#    2421     offsets = np.column_stack([xs, ys])
# -> 2423 self.update_scalarmappable()
#    2425 if not transform.is_affine:
#    2426     coordinates = self._coordinates.reshape((-1, 2))
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/collections.py:923, in Collection.update_scalarmappable(self)
#     921         # pcolormesh, scatter, maybe others flatten their _A
#     922         self._alpha = self._alpha.reshape(self._A.shape)
# --> 923     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     925 if self._face_is_mapped:
#     926     self._facecolors = self._mapped_colors
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:367, in _ColorizerInterface.to_rgba(self, x, alpha, bytes, norm)
#     337 def to_rgba(self, x, alpha=None, bytes=False, norm=True):
#     338     """
#     339     Return a normalized RGBA array corresponding to *x*.
#     340
#    (...)    365
#     366     """
# --> 367     return self._colorizer.to_rgba(x, alpha=alpha, bytes=bytes, norm=norm)
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colorizer.py:157, in Colorizer.to_rgba(self, x, alpha, bytes, norm)
#     155 x = ma.asarray(x)
#     156 if norm:
# --> 157     x = self.norm(x)
#     158 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     159 return rgba
#
# File ~/Projects/StudentUnion/Students/Elouen/GreenSloth/.pixi/envs/default/lib/python3.13/site-packages/matplotlib/colors.py:2679, in _make_norm_from_scale.<locals>.Norm.__call__(self, value, clip)
#    2677 t_vmin, t_vmax = self._trf.transform([self.vmin, self.vmax])
#    2678 if not np.isfinite([t_vmin, t_vmax]).all():
# -> 2679     raise ValueError("Invalid vmin or vmax")
#    2680 t_value -= t_vmin
#    2681 t_value /= (t_vmax - t_vmin)
#
# ValueError: Invalid vmin or vmax
